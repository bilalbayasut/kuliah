# %% [markdown]
# # What will we learn ?
#
# ## Chapter 1 - Introduction
# * What is react ?
# * Who is using react ?
# * Core concept of react ?
# * Why react ?
# * How to use react ?
#
# ## Chapter 2 - Installation
# * How to install react
# * Creating Hello World app
#
# ## Chapter 3 - Onwards
# * Troubleshooting React Native Installs
# * Project Directory Walkthrough
# * Getting content on screen
# * React vs React Native
# * Creating component with JSX
# * Registering component
# * Desctructing Imports
# * Application Outline
# * The header component
# * Consuming file exports
#
# ## Chapter 4 - Making great looking apps
# * Styling with react native
# * More on styling components
# * Introduction to Flexbox
# * Header Styling
# * Making the header reusable
#
# ## Chapter 5 - HTTP Requests with react native
# * Sourcing album data
# * List component boilerplate
# * Class based components
# * Lifecycle methods
# * Network requests
# * component level state
# * More on component level state
# * Rendering a list of component
# * Displaying individual albums
# * Fantastic reusable components
# * Displaying individual albums
# * Fantastic reusable components - cards
# * Styling a card
# * Passing components as props
# * Dividing cards into sections
#
# ## Chapter 6 - Handling Component Layout
# * Mastering layout with flexbox
# * Positioning of Elements on Mobile
# * More on styling
# * Images with react native
# * Displaying album artwork
# * Making content scrollable
# * Handling user input with buttons
# * Styling of buttons with UX considerations
# * Responding to user input
# * Linking between mobile apps
# * Setting button text by props
# * App wrapup
#
# ## Authentication with firebase
#
# ## Processing authentication credentials
#
# ## Digging deeper with redux
#
# ## Back to react
#
# ## Rendering list the right way
#
# ## Not done yet
#
# ## Handling data in react vs redux
#
# ## Don't mutate the state
#
# ## Navigating users around
#
# ## Firebase as a data store
#
# ## Code reuse - edit vs create
